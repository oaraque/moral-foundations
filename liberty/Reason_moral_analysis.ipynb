# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import nltk
from nltk.corpus import stopwords

# %%
import warnings

# %%
import string

# %%
import json
import itertools

# %%
from collections import defaultdict
import seaborn as sns

# %%
from collections import OrderedDict

# %%
import matplotlib.pyplot as plt

# %%
from functools import reduce

# %%
import functools
print = functools.partial(print, flush=True)

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.cm as cm

# %%
import moralstrength

# %%
import os

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 623 kB/s eta 0:00:01    |█████████████████               | 6.4 MB 4.3 MB/s eta 0:00:02
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from en_core_web_sm==2.3.1) (2.3.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.4)
# Requirement already satisfied: numpy>=1.15.0 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.19.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.1.3)
# Requirement already satisfied: setuptools in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (52.0.0.post20210125)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.56.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.25.1)
# Requirement already satisfied: thinc==7.4.1 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.1)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/kkalimeri/miniconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.26.3)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy import displacy
import en_core_web_sm
import gc
import sys

# %%
import statistics

# %%
import unicodedata
import itertools

# %%
from moralstrength.moralstrength import estimate_morals

# %% [markdown]
# #### Load Morals

# %%
moral_list = ['authority','care', 'fairness', 'loyalty', 'purity']

# %%
with open('./../../../ymejova/masks/Sentiment_Moral_Lexicons/moral_dictionary.json', 'r') as fp:
    moral_dictionary = json.load(fp)

# %%
# fill in the missing records
for m in moral_list:
    for k1 in moral_dictionary.keys():
        if m not in moral_dictionary[k1].keys():
            moral_dictionary[k1].update({m : np.nan})

# %%
#sort morals in the dictionary
for k,v in moral_dictionary.items():
    d = moral_dictionary[k]
    moral_dictionary[k] = OrderedDict(sorted(d.items()))

# %%
def moral_estimation(message):
    with warnings.catch_warnings():
        warnings.filterwarnings('ignore')
        lst = []
        t = " ".join(re.findall(r"[a-zA-Z0-9]+", message))
        lem =nlp(str(t),disable=['parser', 'tagger','ner']) 
        if len([y for y in lem if not y.is_stop and y.pos_ != 'PUNCT'])!=0:
            for text in [x.lemma_ for x in [y for y in lem if not y.is_stop and y.pos_ != 'PUNCT']]:
                if text in moral_dictionary:
                    lst.append(tuple(moral_dictionary[text].values()))
                else:
                    lst.append(tuple(np.full(5, np.nan)))
            result = tuple(np.nanmean(lst, axis=0))
        else:
            result = tuple(np.full(5, np.nan))

        return(result)

# %% [markdown]
# ### Import Dataset

# %%
files = os.listdir('./../data/reason/meta/')

# %%
id_ =[]
df_=pd.DataFrame()
for f in files:
    id_.append(pd.Series(f).str.split('_')[0][0])

df_['Meta_ID'] = pd.Series(id_)
metafiles = df_.Meta_ID.values

# %%
files = os.listdir('./../data/reason/text/')
id_ =[]
df_t=pd.DataFrame()

for f in files:
    id_.append(pd.Series(f).str.split('_')[0][0])

df_t['Text_ID'] = pd.Series(id_)
textfiles = df_t.Text_ID.values

# %%
df_.shape, df_t.shape
# Out:
# ((14319, 1), (14319, 1))

# %% [markdown]
# ### get metadata files

# %%
df_meta = pd.DataFrame(columns={'author','keywords', 'published_time', 'section', 'summary', 'title','url'})

# %%
df_list = []

for file in metafiles:
    try:
        df = pd.read_csv('./../data/reason/meta/'+file+'_meta.txt',sep='\t',warn_bad_lines=False,error_bad_lines=False).T
        df_list.append(df)
    except:
        pass

# %%
df_ = pd.DataFrame()
df_meta = pd.DataFrame()

for i in np.arange(0,len(df_list)):
    df_ = df_list[i]
    df_.columns = df_.iloc[0]
    df_ = df_[1:]
    df_['ID'] = metafiles[i]
    df_meta = df_meta.append(df_)
# Out:
# /home/kkalimeri/miniconda3/envs/cloneldaenv/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_meta
# Out:
# title                                              index  \
# 0                                   Does 21  Save Lives?
# 1                                       Flat-Bread Truck
# 2                            Thunder on the Center-Right
# 3                                    Curbing school cops
# 4            The Perils of Global Libertarian Utopianism
# 5                                              Brickbats
# 6                           Darkness and Scattered Light
# 7                                      Living In Freedom
# 8                                                Ad Vice
# 9                                    Cut Taxes and Spend
# 10                                       Stateless Magic
# 11                                                Fed Up
# 12                                Prediction or Warning?
# 13                                         Benign Cells?
# 14                                          Dogs vs. DNA
# 15                                     The Image of Mann
# 16                                   Selling Opportunity
# 17                              Carbon-Based Prohibition
# 18                        America's Internal Checkpoints
# 19                                         Balance Sheet
# 20                                          Brief Review
# 21                                          Road Warrior
# 22                       Selected Skirmishes: Holy Water
# 23                                  Metropolitan Visions
# 24                                       Hong Kong Blues
# 25                                   Disarmed by Mistake
# 26                              Securing Future Retirees
# 27                                  Data: Global Dumping
# 28                                         Without Merit
# 29                                            Book Hints
# ...                                                  ...
# 14100                                     Editor's Notes
# 14101                         The Slow Fade of Meatspace
# 14102  American Taxpayers Are Subsidizing Ultra-Cheap...
# 14103                                  Blade Runner 2049
# 14104             The President's Rotten Record on Trade
# 14105                                      Dioxin Doubts
# 14106                                        Lost Causes
# 14107                   Thinking about Strategic Defense
# 14108                                            Letters
# 14109                              The Big Green Monster
# 14110                        Planning Our Way to Serfdom
# 14111              Life & Liberty: Hooray for Hollywood!
# 14112                               Tom's Last Cigarette
# 14113                     Soundbite: Narc of the Matinee
# 14114                  For Those Hard Investment Choices
# 14115                           Americans Love Pot Taxes
# 14116                                             Bad Ad
# 14117                       The Misguided War on Sexting
# 14118                                   Supply-Side Boom
# 14119                              Taxes: Mum's the Word
# 14120                                           Quickies
# 14121  David Bowie Was a Time Traveler from Our Hyper...
# 14122  Are Diamonds Forever, and Other Conundrums of ...
# 14123                                      Balance Sheet
# 14124                            Movies: Narc Adaptation
# 14125  Debate: Libertarians Should Support Abortion R...
# 14126                                  Needling Vaccines
# 14127                Editor's Note: Reasons for Optimism
# 14128                Toward a Libertarian Foreign Policy
# 14129                                        Family Ways
#
# title                                            summary              author  \
# 0                   Drinking ages and traffic fatalities        Jacob Sullum
# 1      Are capitalist robber barons conspiring to rui...       Brian Doherty
# 2                          The Weekly Standard turns 10.      W. James Antle
# 3                                       Elementary Abuse       Brian Doherty
# 4      THE STATE POSES the greatest threat to liberty...  Christopher Preble
# 5      Tammie Jackson says students at Missouri's Cen...      Charles Oliver
# 6      Darkness and Scattered Light, by William Irwin...            G. Stine
# 7      Reflections on a free society by America's lea...           Karl Hess
# 8      Coercion: Why We Listen to What "They" Say, by...    Timothy Virkkala
# 9                                   The beast still eats       Brian Doherty
# 10     In the anarchic country of James Enge's fantas...        Jackson Kuhl
# 11                  The problems of the Federal Reserve.    Virginia Postrel
# 12     Russian Spring, by Norman Spinrad, New York: B...      Greg Costikyan
# 13                              Cancer and Mobile Phones       Ronald Bailey
# 14                                K-9 testimony debunked        Radley Balko
# 15     The Myth of the Common School, by Charles Lesl...     Lawrence Uzzell
# 16     Transformation: The Promise and Politics of Em...     John McClaughry
# 17     If some environmentalists have their way, simp...       Russell Seitz
# 18     Refuseniks fight back against feds demanding p...         Wes Kimbell
# 19     Assets Crossed Wires. Fast action prevents par...      Rick Henderson
# 20     Space Enterprise: Beyond NASA, by David P. Gum...         Greg Rehmke
# 21     Roads in a Market Economy, by Gabriel Roth, Br...        Robert Poole
# 22     By the time you read this, you will have alrea...   Thomas W. Hazlett
# 23     New Visions for Metropolitan America, by Antho...        Peter Salins
# 24     Post-takeover, the media forecast is dark and ...     Adam Powell III
# 25                                New York's new gun law        Jacob Sullum
# 26     A proposal before Congress would require the S...      Rick Henderson
# 27     Countries such as the United States, Australia...       Michael Lynch
# 28          Why merit pay won't reform public education.      Nick Gillespie
# 29                 A selective mention of books received         Marty Zupan
# ...                                                  ...                 ...
# 14100  â€¢ INVESTIGATIVE JOURNALISM. We are pleased t...        Robert Poole
# 14101            When will this Internet thing catch on?       Tim Cavanaugh
# 14102  For decades, the U.S. Postal Service has charg...          Mike Riggs
# 14103  Blade Runner 2049, Warner Bros It may have tak...         Robby Soave
# 14104  Why George W. Bush is the most protectionist p...      Bruce Bartlett
# 14105  I don't want dioxin in my breast milk! Hope ex...        Jacob Sullum
# 14106  Some of the Republican party's biggest losers ...    Virginia Postrel
# 14107  What is a rational person to think of the Reag...        Robert Poole
# 14108  Mars: Fact or Folly? After reading John Tierne...        Reason Staff
# 14109  California's latest environmental initiative p...      Steven Hayward
# 14110  It is a regrettable but undeniable fact that e...          F.A. Hayek
# 14111  If you haven't been to the movies lately, you ...      Douglas Borton
# 14112                               Toons go cold turkey        Jacob Sullum
# 14113  For nearly four decades, the Motion Picture As...        Kerry Howley
# 14114  The Hard Money Book, by Steven K. Beckner, New...        John Pugsley
# 14115  But hyping cannabis cash as a source of govern...        Jacob Sullum
# 14116                             Peanuts, candy, heroin      Julian Sanchez
# 14117  America is taking a punitive approach to teens...      Noah Berlatsky
# 14118  The long-awaited tax cut is fueling the recove...       Arthur Laffer
# 14119  By now everyone knows that nothing's going to ...      Timothy Condon
# 14120  As somebody said in the Los Angeles Times, "Th...     Bill Birmingham
# 14121            The star who made it cool to be a freak      Nick Gillespie
# 14122  The Second Creation: Makers of the Revolution ...     Gregory Benford
# 14123  Assets Eminent Victory The Ohio Supreme Court ...         Jeff Taylor
# 14124  In Crisis and Leviathan, Robert Higgs argues t...        Jacob Sullum
# 14125                 Does a fetus have a right to live?        Tibor Machan
# 14126                              Autism's day in court       Ronald Bailey
# 14127  Let me state the obvious: In today's political...      Nick Gillespie
# 14128  Rand Paul moves the ball on a long-overdue pro...          Matt Welch
# 14129  The Divorce Culture: How Divorce Became an Ent...      Nick Gillespie
#
# title                                           keywords  \
# 0                                                    NaN
# 1                                              Antitrust
# 2                                    Politics|Iraq|Media
# 3                                      Police in Schools
# 4                                                    NaN
# 5                                               Politics
# 6                                                    NaN
# 7      Anarchism|Decentralization|Corporate Power|Emp...
# 8                              Internet|Media|Television
# 9                                                    NaN
# 10                                Book Reviews|Anarchism
# 11                 Deregulation|Congress|Hillary Clinton
# 12                                       Science Fiction
# 13     Public Health|Science|Technology|Telecommunica...
# 14                                       Animal Behavior
# 15                                                   NaN
# 16                  Alcohol|Politics|Social Issues|Labor
# 17                                                   NaN
# 18                            Immigration|Borders|Police
# 19     Civil Liberties|Congress|Social Issues|Technol...
# 20                                                   NaN
# 21                Taxes|Technology|Transportation Policy
# 22                                                   NaN
# 23     Deregulation|Energy|Land Use|Privatization|Reg...
# 24      China|Corruption|Internet|Media|Print|Technology
# 25                                                   NaN
# 26                                                   NaN
# 27                                  China|European Union
# 28                                   Guns|History|Movies
# 29                                                   NaN
# ...                                                  ...
# 14100                                                NaN
# 14101                                   Internet|Culture
# 14102       Policy|Post Office|Subsidies|Globalism|China
# 14103                                                NaN
# 14104      Presidential History|Free Trade|Globalization
# 14105                                                NaN
# 14106                                                NaN
# 14107                                                NaN
# 14108  History|Congress|Third Parties|Regulation|Scie...
# 14109                                                NaN
# 14110                                                NaN
# 14111                                                NaN
# 14112                                                NaN
# 14113                                  Movies|Censorship
# 14114                                                NaN
# 14115  Marijuana|Marijuana Ballot Initiatives|Drug Le...
# 14116              Ron Paul|Television|Drug Policy|Drugs
# 14117  Internet|Sex|Sex Crimes|Teenagers|Cellphones|M...
# 14118                                                NaN
# 14119                                                NaN
# 14120                                                NaN
# 14121                   Music|Popular Culture|Obituaries
# 14122                                                NaN
# 14123                                                NaN
# 14124                                                NaN
# 14125                                                NaN
# 14126                                                NaN
# 14127        Technology|Property Rights|Politics|History
# 14128  Rand Paul|Foreign Policy|Executive Power|Barac...
# 14129                Family Issues|Social Issues|Welfare
#
# title             published_time section  \
# 0      2007-11-01T16:43:00+00:00   Posts
# 1      1997-08-01T04:00:00+00:00   Posts
# 2      2006-04-01T05:00:00+00:00   Posts
# 3      2010-03-21T23:44:00+00:00   Posts
# 4      2003-08-01T16:00:00+00:00   Posts
# 5      2013-04-09T15:03:00+00:00   Posts
# 6      1979-04-01T17:00:00+00:00   Posts
# 7      1978-05-01T16:00:00+00:00   Posts
# 8      2000-04-01T05:00:00+00:00   Posts
# 9      2008-02-01T17:45:00+00:00   Posts
# 10     2012-11-02T16:00:00+00:00   Posts
# 11     1994-07-01T04:00:00+00:00   Posts
# 12     1992-01-01T17:00:00+00:00   Posts
# 13     2007-03-01T15:45:00+00:00   Posts
# 14     2009-10-01T04:02:00+00:00   Posts
# 15     1990-06-01T16:00:00+00:00   Posts
# 16     1999-03-01T05:00:00+00:00   Posts
# 17     2008-07-23T16:00:00+00:00   Posts
# 18     2013-12-28T17:00:00+00:00   Posts
# 19     1996-01-01T05:00:00+00:00   Posts
# 20     1991-02-01T19:11:00+00:00   Posts
# 21     1996-08-01T04:00:00+00:00   Posts
# 22     1991-11-01T19:58:00+00:00   Posts
# 23     1994-12-01T05:00:00+00:00   Posts
# 24     1997-06-01T04:00:00+00:00   Posts
# 25     2013-07-10T21:35:00+00:00   Posts
# 26     1989-12-01T17:00:00+00:00   Posts
# 27     2001-11-01T05:00:00+00:00   Posts
# 28     2000-10-01T04:00:00+00:00   Posts
# 29     1979-03-01T17:00:00+00:00   Posts
# ...                          ...     ...
# 14100  1980-07-01T16:00:00+00:00   Posts
# 14101  2010-06-22T11:00:00+00:00   Posts
# 14102  2019-11-11T11:00:31+00:00   Posts
# 14103  2018-01-01T17:00:00+00:00   Posts
# 14104  2006-06-06T04:00:00+00:00   Posts
# 14105  1991-12-01T17:00:00+00:00   Posts
# 14106  1993-01-01T05:00:00+00:00   Posts
# 14107  1981-12-01T17:00:00+00:00   Posts
# 14108  1999-05-01T04:00:00+00:00   Posts
# 14109  1990-06-01T16:00:00+00:00   Posts
# 14110  1977-03-01T17:00:00+00:00   Posts
# 14111  1986-04-01T17:00:00+00:00   Posts
# 14112  2006-12-01T14:49:00+00:00   Posts
# 14113  2007-01-01T20:21:00+00:00   Posts
# 14114  1980-06-01T16:00:00+00:00   Posts
# 14115  2016-01-20T11:00:00+00:00   Posts
# 14116  2003-08-01T04:00:00+00:00   Posts
# 14117  2015-04-09T13:00:00+00:00   Posts
# 14118  1983-05-01T16:00:00+00:00   Posts
# 14119  1984-05-01T16:00:00+00:00   Posts
# 14120  1977-04-01T17:00:00+00:00   Posts
# 14121  2016-03-12T11:00:00+00:00   Posts
# 14122  1986-12-01T17:00:00+00:00   Posts
# 14123  2006-10-01T14:01:00+00:00   Posts
# 14124  1992-04-01T17:00:00+00:00   Posts
# 14125  2018-09-13T10:00:00+00:00   Posts
# 14126  2008-07-04T16:00:00+00:00   Posts
# 14127  2005-11-01T05:00:00+00:00   Posts
# 14128  2013-03-11T17:30:00+00:00   Posts
# 14129  1997-10-01T04:00:00+00:00   Posts
#
# title                                                url  \
# 0      https://reason.com/2007/11/01/does-21-save-lives/
# 1        https://reason.com/1997/08/01/flat-bread-truck/
# 2      https://reason.com/2006/04/01/thunder-on-the-c...
# 3      https://reason.com/2010/03/21/curbing-school-c...
# 4      https://reason.com/2003/08/01/the-perils-of-gl...
# 5           https://reason.com/2013/04/09/brickbats-229/
# 6      https://reason.com/1979/04/01/darkness-and-sca...
# 7       https://reason.com/1978/05/01/living-in-freedom/
# 8               https://reason.com/2000/04/01/ad-vice-2/
# 9      https://reason.com/2008/02/01/cut-taxes-and-sp...
# 10        https://reason.com/2012/11/02/stateless-magic/
# 11               https://reason.com/1994/07/01/fed-up-2/
# 12     https://reason.com/1992/01/01/prediction-or-wa...
# 13           https://reason.com/2007/03/01/benign-cells/
# 14            https://reason.com/2009/10/01/dogs-vs-dna/
# 15      https://reason.com/1990/06/01/the-image-of-mann/
# 16     https://reason.com/1999/03/01/selling-opportun...
# 17     https://reason.com/2008/07/23/carbon-based-pro...
# 18     https://reason.com/2013/12/28/americas-interna...
# 19      https://reason.com/1996/01/01/balance-sheet-136/
# 20        https://reason.com/1991/02/01/brief-review-18/
# 21           https://reason.com/1996/08/01/road-warrior/
# 22     https://reason.com/1991/11/01/selected-skirmis...
# 23     https://reason.com/1994/12/01/metropolitan-vis...
# 24        https://reason.com/1997/06/01/hong-kong-blues/
# 25     https://reason.com/2013/07/10/disarmed-by-mist...
# 26     https://reason.com/1989/12/01/securing-future-...
# 27     https://reason.com/2001/11/01/data-global-dump...
# 28          https://reason.com/2000/10/01/without-merit/
# 29           https://reason.com/1979/03/01/book-hints-7/
# ...                                                  ...
# 14100    https://reason.com/1980/07/01/editors-notes-37/
# 14101  https://reason.com/2010/06/22/the-slow-fade-of...
# 14102  https://reason.com/2019/11/11/american-taxpaye...
# 14103   https://reason.com/2018/01/01/blade-runner-2049/
# 14104  https://reason.com/2006/06/06/the-presidents-r...
# 14105       https://reason.com/1991/12/01/dioxin-doubts/
# 14106       https://reason.com/1993/01/01/lost-causes-2/
# 14107  https://reason.com/1981/12/01/thinking-about-s...
# 14108         https://reason.com/1999/05/01/letters-332/
# 14109  https://reason.com/1990/06/01/the-big-green-mo...
# 14110  https://reason.com/1977/03/01/planning-our-way...
# 14111  https://reason.com/1986/04/01/life-liberty-hoo...
# 14112  https://reason.com/2006/12/01/toms-last-cigare...
# 14113         https://reason.com/2007/01/01/soundbite-4/
# 14114  https://reason.com/1980/06/01/for-those-hard-i...
# 14115  https://reason.com/2016/01/20/americans-love-p...
# 14116            https://reason.com/2003/08/01/bad-ad-2/
# 14117  https://reason.com/2015/04/09/the-misguided-wa...
# 14118    https://reason.com/1983/05/01/supply-side-boom/
# 14119       https://reason.com/1984/05/01/mums-the-word/
# 14120          https://reason.com/1977/04/01/quickies-4/
# 14121  https://reason.com/2016/03/12/david-bowie-was-...
# 14122  https://reason.com/1986/12/01/are-diamonds-for...
# 14123    https://reason.com/2006/10/01/balance-sheet-80/
# 14124     https://reason.com/1992/04/01/narc-adaptation/
# 14125  https://reason.com/2018/09/13/proposition-libe...
# 14126   https://reason.com/2008/07/04/needling-vaccines/
# 14127  https://reason.com/2005/11/01/editors-note-rea...
# 14128  https://reason.com/2013/03/11/toward-a-liberta...
# 14129         https://reason.com/1997/10/01/family-ways/
#
# title                                ID
# 0      69ff8431206c0a7f85be88f881bf0c45
# 1      bd5d11929e3259b0d7d467d3bca9a232
# 2      ee997824355396272b3c67fe27752222
# 3      56d7fe14fb6b21fbdaf8265f3c363d25
# 4      fc0fa288f03bc1f88d82054c876b1128
# 5      99a51463527eabcd214df5de6b370fc4
# 6      b211c373e9ab72ca09179d17acbc9f39
# 7      e161719ac9782599e4025c3f41596434
# 8      22d9140d5edac10b629a9351276ec90d
# 9      9fa9b93d415010a8f4bb6c894874ad34
# 10     1dbc4a0f356c80b7370a96e2b5a636ce
# 11     1bdbfbef6cc18876753594adfa4fcd0b
# 12     8d195a9ac532257a944c5253d767ba79
# 13     3b4a5d7e6360d0a7a952a46eace240cf
# 14     fe516ec3e7912dd05c304f6cd6e40799
# 15     329059b9d8eaaf67f1b9c3078d2ff9b5
# 16     90d09b98685b4d5ae99bdec3d6b56d60
# 17     3537e17cf5eee80658352b48a45a025d
# 18     6a6742544052a5803c62cf9a7ffdb200
# 19     a402e45a78480b21cd4d75d5b6a449ba
# 20     b1b67f17ff253b9d26449ba1e9e63690
# 21     ed2c272ee4f60d25281e18e871ac40a2
# 22     6fe5962917223a72715cee5a294a860d
# 23     cfbd17c86fdbae973a1ea09637396c70
# 24     4cbe53aef3cb15716e9cb10cd7a50438
# 25     4113e34c3f254046290deea1ebc96654
# 26     cf71de3b036e0c8595e9ff1a9c832f7a
# 27     72f9db686660def79e25e127559449be
# 28     7613480ac364d1dc548a98aabad5833c
# 29     9617d92270fde367c49a48b1dc126d8d
# ...                                 ...
# 14100  9082dabcf11292736eb664a06fe35d9b
# 14101  b04f4740299fc6ce2145bf2376b29bd7
# 14102  2c04227e4179fbe71d38117dd8105aca
# 14103  9cb900fb0e343d635ac17fb020d9e99e
# 14104  0f6b29b1ef937c6def7130ca64f80274
# 14105  b1e6e57154cebafafe25865b3bd0c943
# 14106  d628eebadd5c09e13ccc173e1f27a3d2
# 14107  93542a45abda254694797efe87f2cb0e
# 14108  a5dbf1f1ce18ca4f099452a01ebe0bf6
# 14109  bcac1076a99ea298a3892062e78cb20e
# 14110  4df5f5036669e6e3b73e869bafd10684
# 14111  3c4582ccd0520d22fe751d3afe9e9dc0
# 14112  b8cdeb8f7604f7f69d32a8424b9f0ee0
# 14113  e560daf908c34ff82933f76c82e5229c
# 14114  418263ab2edf6d01e3147d63a8ae19cc
# 14115  c56120a26ac8a32d23c4be94dc64185a
# 14116  2e76e767d33b23f47592a8f4e6cdafef
# 14117  7dc247a3b4a10a3e334c186ddad6ae1e
# 14118  38e70465a42da8020f58c4dfa8c1093f
# 14119  2d3f184a34d7b634bae057386b2efff6
# 14120  c3eb253604cd8dc8b5957da4b353f9dc
# 14121  103a2372e7316474609ee242b42feda1
# 14122  108887c1d850ef3c93680cb1d3d8aa6d
# 14123  a68ec40a08547df8e2d58cb3dc3babdf
# 14124  9a117c499e63e994617ed22aef95fd2e
# 14125  8ad33edaaf82cd937dc20fcc887ddc72
# 14126  0f1b4b25589e9d5e734f37fe8c47609d
# 14127  cb560bfdc03fe032441dc4d6c1805751
# 14128  d048c404ddbeaff67005658d748748ca
# 14129  c9700901cadb2929afc41d5fb4e72d7e
#
# [14130 rows x 8 columns]

# %%
df_meta.reset_index().to_csv('./../data/reason/output_data/metadata.csv',sep='\t')

# %% [markdown]
# ### get text

# %%
df_list = []
df=pd.DataFrame()
for file in textfiles:
    with open('./../data/reason/text/'+file+'_text.txt', "rb") as f:
        t = f.read().decode(errors="replace")
    df_list.append(t)

# %%
df_t['Text_Corpus'] = pd.DataFrame(df_list)

# %%
df_t.rename(columns={0:'ID',1:'Text'},inplace=True)

# %%
df_t.to_csv('./../data/reason/output_data/textdata.csv',sep='\t')

# %% [markdown]
# ### Clean the text

# %%
nlp = en_core_web_sm.load()

# %%
# %%time
re_url = re.compile(r'https?:\/\/.*[\r\n]*', flags=re.U)
#re_rtw = re.compile(r'RT', flags=re.U)
re_htg = re.compile(r'#', flags=re.U) # remove hashtag sign
#re_htg = re.compile(r'#[\w]+ ?', flags=re.U)   # remove hashtags
re_hnd = re.compile(r'@\w+ ?', flags=re.U)
re_wrd = re.compile(r'[^\w]+ ', flags=re.U)
re_num = re.compile(r'[0-9]+', flags=re.U)

def preprocessing(txt):
    t = txt
    t = re_url.sub('', t)
    t = re_htg.sub('', t)
#    t = re_rtw.sub(' ', t)
    t = re_hnd.sub(' ', t)
    t = re_wrd.sub(' ', t)
    t = re_num.sub(' ', t)
    
    #t = emoji_pattern.sub(r'', t)
    #t = emoji.get_emoji_regexp().sub(r'', t)  #.decode('utf8')  # Remove emojis
   # t = emoji.demojize(t)  # Convert emojis to text
    return t.strip().lower()
# Out:
# CPU times: user 1.47 ms, sys: 0 ns, total: 1.47 ms
# Wall time: 1.42 ms

# %%
# cleaning master function
remove = string.punctuation
remove = remove.replace("-", "") # don't remove hyphens
pattern = r"[{}]".format(remove) # create the pattern

def clean_tweet(tweet):
    if pd.isnull(tweet):
        return(np.nan)
    else:
        
     
        tweet = re.sub(pattern, "", tweet) 

        tweet = tweet.lower() # lower case   

        tweet = ''.join([i for i in tweet if not i.isdigit()])
        tweet = _strip_accents(tweet)
        tweet = re.sub(r'&amp', 'and', tweet)
        tweet = re.sub(r'[^A-Za-z]', ' ', tweet)
        tweet = re.sub('\s+', ' ', tweet) #remove double spacing
       # tweet = re.sub('([0-9]+)', '', tweet) # remove numbers
        tweet_token_list = [word for word in tweet.split(' ')
                                if word not in my_stopwords] # remove stopwords
        tweet = ' '.join(tweet_token_list)
        return tweet

def _strip_accents(text):
    try:
        text = unicode(text, 'utf-8')
    except NameError: # unicode is a default on python 3 
        pass

    text = unicodedata.normalize('NFD', text)\
           .encode('ascii', 'ignore')\
           .decode("utf-8")
    return str(text)

# %%
my_stopwords = nltk.corpus.stopwords.words('english')
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS
my_stopwords = my_stopwords + list(spacy_stopwords)

# %%
df_t.head()
# Out:
#                             Text_ID  \
# 0  88d51a4c8c051ce7bc39994d31e45268
# 1  657ac0524e600bb6d2e2ae80f0905f25
# 2  0f1f3e303bfb33e3337a7ae41218408b
# 3  3b7023a103008cc222b44d0403bfecb4
# 4  380aad1318799f477818ea188b4630ed
#
#                                          Text_Corpus
# 0  California now has a central anti-terrorism ce...
# 1  • Libertarians who would like an excuse to cel...
# 2  Disturbed about the obvious disorders of educa...
# 3  It was May 1993. Barely two years earlier, a f...
# 4  In Pennsylvania, you can buy liquor only at th...

# %%
df_t.loc[:,'text_p'] = df_t['Text_Corpus'].map(lambda x: _strip_accents(x))

# %%
df_t['text_clean'] = df_t.text_p.apply(lambda x: clean_tweet(x))

# %% [markdown]
# ### Estimate Morals

# %%
# %%time
df_t[['care', 'fairness', 'loyalty', 'authority', 'purity']]  = estimate_morals(df_t['text_clean'], process=True)
# Out:
# CPU times: user 9min 5s, sys: 1.66 s, total: 9min 7s
# Wall time: 9min 7s

# %%
df_t.head()
# Out:
#                             Text_ID  \
# 0  88d51a4c8c051ce7bc39994d31e45268
# 1  657ac0524e600bb6d2e2ae80f0905f25
# 2  0f1f3e303bfb33e3337a7ae41218408b
# 3  3b7023a103008cc222b44d0403bfecb4
# 4  380aad1318799f477818ea188b4630ed
#
#                                          Text_Corpus  \
# 0  California now has a central anti-terrorism ce...
# 1  • Libertarians who would like an excuse to cel...
# 2  Disturbed about the obvious disorders of educa...
# 3  It was May 1993. Barely two years earlier, a f...
# 4  In Pennsylvania, you can buy liquor only at th...
#
#                                               text_p  \
# 0  California now has a central anti-terrorism ce...
# 1   Libertarians who would like an excuse to cele...
# 2  Disturbed about the obvious disorders of educa...
# 3  It was May 1993. Barely two years earlier, a f...
# 4  In Pennsylvania, you can buy liquor only at th...
#
#                                           text_clean     care fairness  \
# 0  california central anti terrorism center polic...  4.56667      NaN
# 1   libertarians like excuse celebrate set aside ...  1.93333  6.68333
# 2  disturbed obvious disorders education groups c...  8.37679  7.07222
# 3  barely years earlier failed coup attempt marke...  3.86863  7.25982
# 4  pennsylvania buy liquor derided state store se...      3.1      4.5
#
#    loyalty authority   purity
# 0  5.10722   4.56667      NaN
# 1  5.11111   5.05317  2.85714
# 2  7.59375   5.47083        8
# 3  5.55885   6.68495  6.71581
# 4      NaN   5.65556      NaN

# %%
gc.collect()
# Out:
# 0

# %%
df_t_m = df_t.loc[:,['Text_ID','authority','care','fairness','loyalty','purity']].melt(id_vars=['Text_ID'], value_vars=['authority','care','fairness','loyalty','purity',],
    var_name='Morals', value_name='Value')

# %%
df_t_m[df_t_m.Morals=='care'].Value.dropna().std()
# Out:
# 1.7867136072339505

# %%
plt.figure(figsize=(10,5))
sns.pointplot(x =df_t_m.Morals, y= df_t_m.Value.astype(float), data = df_t_m,join=False, order = ['care', 'fairness', 'loyalty', 'authority', 'purity'] ,dodge=True, estimator=np.mean, capsize=.2,ci='sd')
plt.legend()
plt.ylim(1, 9)
plt.ylabel('Moral Valence')
plt.xlabel('')
plt.savefig('./../figs/reason/TotalMedianDifference.pdf',format='pdf', transparent=True)
# Out:
# No handles with labels found to put in legend.

# %%
gc.collect()
# Out:
# 13816

# %%
df_meta.head()
# Out:
# title                                                                                  summary  \
# Does 21  Save Lives?                                      Drinking ages and traffic fatalities
# Flat-Bread Truck                             Are capitalist robber barons conspiring to rui...
# Thunder on the Center-Right                                      The Weekly Standard turns 10.
# Curbing school cops                                                           Elementary Abuse
# The Perils of Global Libertarian Utopianism  THE STATE POSES the greatest threat to liberty...
#
# title                                                    author  \
# Does 21  Save Lives?                               Jacob Sullum
# Flat-Bread Truck                                  Brian Doherty
# Thunder on the Center-Right                      W. James Antle
# Curbing school cops                               Brian Doherty
# The Perils of Global Libertarian Utopianism  Christopher Preble
#
# title                                                   keywords  \
# Does 21  Save Lives?                                         NaN
# Flat-Bread Truck                                       Antitrust
# Thunder on the Center-Right                  Politics|Iraq|Media
# Curbing school cops                            Police in Schools
# The Perils of Global Libertarian Utopianism                  NaN
#
# title                                                   published_time  \
# Does 21  Save Lives?                         2007-11-01T16:43:00+00:00
# Flat-Bread Truck                             1997-08-01T04:00:00+00:00
# Thunder on the Center-Right                  2006-04-01T05:00:00+00:00
# Curbing school cops                          2010-03-21T23:44:00+00:00
# The Perils of Global Libertarian Utopianism  2003-08-01T16:00:00+00:00
#
# title                                       section  \
# Does 21  Save Lives?                          Posts
# Flat-Bread Truck                              Posts
# Thunder on the Center-Right                   Posts
# Curbing school cops                           Posts
# The Perils of Global Libertarian Utopianism   Posts
#
# title                                                                                      url  \
# Does 21  Save Lives?                         https://reason.com/2007/11/01/does-21-save-lives/
# Flat-Bread Truck                               https://reason.com/1997/08/01/flat-bread-truck/
# Thunder on the Center-Right                  https://reason.com/2006/04/01/thunder-on-the-c...
# Curbing school cops                          https://reason.com/2010/03/21/curbing-school-c...
# The Perils of Global Libertarian Utopianism  https://reason.com/2003/08/01/the-perils-of-gl...
#
# title                                                                      ID
# Does 21  Save Lives?                         69ff8431206c0a7f85be88f881bf0c45
# Flat-Bread Truck                             bd5d11929e3259b0d7d467d3bca9a232
# Thunder on the Center-Right                  ee997824355396272b3c67fe27752222
# Curbing school cops                          56d7fe14fb6b21fbdaf8265f3c363d25
# The Perils of Global Libertarian Utopianism  fc0fa288f03bc1f88d82054c876b1128

# %%
df_meta.shape
# Out:
# (14130, 7)

# %% [markdown]
# ### Comapre Reason with All sides on the common keywords

# %%
k = df_meta.keywords.dropna().str.split('|')

# %%
k = pd.DataFrame(k).reset_index()

# %%
keywords = np.unique([*itertools.chain.from_iterable(k.keywords)])

# %%
keywords
# Out:
# array(['10th Amendment', '14th Amendment', '1968', ..., 'tenure',
#        'victims', 'wealth tax'], dtype='<U43')

# %%
keywords = pd.DataFrame(keywords)

# %%
keywords2check = keywords[keywords.iloc[:,0].isin(df_meta_all_sides['Tags:'].unique())]

# %%
keywords2check.rename(columns={0:"keywords"},inplace=True)
# Out:
# /home/kkalimeri/miniconda3/envs/cloneldaenv/lib/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
for i in keywords2check.keywords.values:
    metafiles_to_retrieve = df_meta.keywords.filter(like=i, axis=0).index
    metafiles_id = df_meta.loc[metafiles_to_retrieve].ID.values
    d_scores = df_t[df_t.Text_ID.isin(metafiles_id)]
    moral_scores = d_scores.loc[:,['Text_ID','authority','care','fairness','loyalty','purity']].melt(id_vars=['Text_ID'], value_vars=['authority','care','fairness','loyalty','purity',],
    var_name='Morals', value_name='Value')
    fig = plt.figure(figsize=(10,5))
    try:
        sns.pointplot(x =moral_scores.Morals, y= moral_scores.Value, data = moral_scores,dodge=True,join=False, estimator=np.median, capsize=.2,order=['care', 'fairness', 'loyalty', 'authority', 'purity'])   
        plt.title(i)
        plt.ylabel('Moral Valence')
        plt.ylim(0, 9)
        plt.xlabel('')
        plt.savefig('./../figs/reason/Reason_'+str(i)+'.pdf',format='pdf', transparent=True)
        plt.close(fig)
    except:
        print(i)
        continue
    
    gc.collect()
# Out:
# Campaign Finance
# Culture
# Food
# National Defense
# Palestine
# Science
# South Korea
# Taxes
# Treasury

# %%
gc.collect()
# Out:
# 117844
